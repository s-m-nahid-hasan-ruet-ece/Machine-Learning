# %% [markdown]
# 1.  Python list, boolean variables
# 2.  Sets , dictionaries, Tuples
# 3.  Numpy and inbuilt functions
# 4.  Pandas, Data frame and data series
# 5.  pandas(reading csv with variaous parameters)
# 6.  Map functions
# 7.  filter funtions
# 8.  python list comprehension
# 9.  Access modifiers
# 10. Univariate, bivariate and multivariate analysis

# %%
#  map(fun, iter)

def square(n):
    return n*n

numbers = (1,2,3,4)

result = map(square, numbers)

print(list(result))
# Out:
# [1, 4, 9, 16]

# %%
#  Filtering an Array using filter()
#  filter(function, iterable)


array =  [3, 100, 4, 9, 10, 15, 18, 22]

def findEven(x):
    if(x%2==0):
        return True
    else:
        return False

evenNums =  filter(findEven, array)

for x in evenNums:
    print(x)
# Out:
# 100
# 4
# 10
# 18
# 22

# %%
array = [(12,32),(32,2), (32,3), (11,43)]


def sort(arg):

    for i in range(4):
        for j in range(i+1,4):
            print(arg[i], arg[j])
            print(arg[i][0], arg[i][1])

sort(array)
# Out:
# (12, 32) (32, 2)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13664/179636359.py in <module>
#       9             print(arg[i][0], ar[i][1])
#      10
# ---> 11 sort(array)
#
# ~\AppData\Local\Temp/ipykernel_13664/179636359.py in sort(arg)
#       7         for j in range(i+1,4):
#       8             print(arg[i], arg[j])
# ----> 9             print(arg[i][0], ar[i][1])
#      10
#      11 sort(array)
#
# NameError: name 'ar' is not defined

# %%
#List Comprehension
numbers = [1,2,3,4,5,7]

sqr = [x*x for x in numbers]
print(sqr)
# Out:
# [1, 4, 9, 16, 25, 49]

# %%
#Determining few points for y from the equation y = x^3 + 2*x^2 -6x + 5 only for positive x values from the given values of x_val

x_vals = [2,6, 9, 10, -17, 18,-32, 20, 30, -10]

y_vals = [(x*x*x+2*x*x-6*x+5) for x in x_vals if x>0]


print("y_vals: ",y_vals)

plt.plot([x for x in x_vals if x>0],y_vals)
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('X vs Y')

plt.show()
# Out:
# y_vals:  [9, 257, 842, 1145, 6377, 8685, 28625]

# %% [markdown]
# #### **Access modifiers**

# %%
# Illustration of Protected Class Members
class Student:
	
	_name = None
	_roll = None
	_branch = None
	

	def __init__(self, name, roll, branch):
		self._name = name
		self._roll = roll
		self._branch = branch
	
	def _displayRollAndBranch(self):

		print("Roll: ", self._roll)
		print("Branch: ", self._branch)


class Geek(Student):

	def __init__(self, name, roll, branch):
				Student.__init__(self, name, roll, branch)
		
	def displayDetails(self):
				
				print("Name: ", self._name)
				
				self._displayRollAndBranch()

obj = Geek("R2J", 1706256, "Information Technology")

obj.displayDetails()
# Out:
# Name:  R2J
# Roll:  1706256
# Branch:  Information Technology

# %%
# Illustration of Private Class Members

class Geek:

	__name = None
	__roll = None
	__branch = None

	def __init__(self, name, roll, branch):
		self.__name = name
		self.__roll = roll
		self.__branch = branch


	def __displayDetails(self):
		

		print("Name: ", self.__name)
		print("Roll: ", self.__roll)
		print("Branch: ", self.__branch)

	def accessPrivateFunction(self):
			
		self.__displayDetails()

obj = Geek("R2J", 1706256, "Information Technology")

obj.accessPrivateFunction()
# Out:
# Name:  R2J
# Roll:  1706256
# Branch:  Information Technology

# %% [markdown]
# ####  **Univariate, bivariate and multivariate analysis**
#
# When it comes to the level of analysis in statistics, there are three different analysis techniques that exist. These are:
# - Univariate analysis
# - Bivariate analysis
# - Multivariate analysis
#
# #####  **Univariate Analysis**
#
# This type of data consists of only one variable. The analysis of univariate data is thus the simplest form of analysis since the information deals with only one quantity that changes. It does not deal with causes or relationships and the main purpose of the analysis is to describe the data and find patterns that exist within it.
#
# #####  **Way to Analysis Univariate Analysis:**
#
# - Frequency Distribution Tables
# - Histograms
# - Frequency Polygons
# - Pie Charts
# - Bar Charts
#
#
#
# ####  **Resources**
#
# - https://www.geeksforgeeks.org/univariate-bivariate-and-multivariate-data-and-its-analysis/
# - https://hotcubator.com.au/research/what-is-univariate-bivariate-and-multivariate-analysis/
# - https://www.modernanalyst.com/Careers/InterviewQuestions/tabid/128/ID/4904/Describe-the-difference-between-univariate-bivariate-and-multivariate-analysis.aspx
# - https://www.enjoyalgorithms.com/blog/univariate-bivariate-multivariate-analysis
# - https://medium.com/mlearning-ai/univariate-bivariate-and-multivariate-data-analysis-in-python-341493c3d173

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
card_approval_df=pd.read_csv('../Datasets/clean_dataset.csv')
card_approval_df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
print(card_approval_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB
# ...

# %% [markdown]
# **Columns holding categorical data :** Gender, Married, BankCustomer, Industry, Ethinicity, PriorDefault, Employed, DrivingLicense, Citizen, Approved
# **Columns holding continuous data:** Age, debt, YearsEmployed, CreditScore, Income
#
#
# ###                                        **Univariate Analysis of continuous Variables**

# %%
card_approval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].describe()
# Out:
#               Age        Debt  YearsEmployed  CreditScore         Income
# count  690.000000  690.000000     690.000000    690.00000     690.000000
# mean    31.514116    4.758725       2.223406      2.40000    1017.385507
# std     11.860245    4.978163       3.346513      4.86294    5210.102598
# min     13.750000    0.000000       0.000000      0.00000       0.000000
# 25%     22.670000    1.000000       0.165000      0.00000       0.000000
# 50%     28.460000    2.750000       1.000000      0.00000       5.000000
# 75%     37.707500    7.207500       2.625000      3.00000     395.500000
# max     80.250000   28.000000      28.500000     67.00000  100000.000000

# %%
sns.histplot(card_approval_df.Age,kde=True)
plt.title('Age vs Count of Account Holding')
# Out:
# Text(0.5, 1.0, 'Age vs Count of Account Holding')

# %%
sns.histplot(card_approval_df.YearsEmployed,kde=True)
plt.title('YearsEmployed vs Count of Account Holding')
# Out:
# Text(0.5, 1.0, 'YearsEmployed vs Count of Account Holding')

# %% [markdown]
# ###  **Univariate Analysis of Categorical Variables**

# %%
sns.countplot(card_approval_df.Gender)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(card_approval_df.BankCustomer)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BankCustomer', ylabel='count'>

# %%
sns.countplot(card_approval_df.Ethnicity)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
sns.countplot(card_approval_df.Approved)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Approved', ylabel='count'>

# %% [markdown]
# ### **Bivariate Analysis**
#
# Bivariate analysis is slightly more analytical than Univariate analysis. When the data set contains two variables and researchers aim to undertake comparisons between the two data set then Bivariate analysis is the right type of analysis technique.

# %% [markdown]
# ### **Bivariate Analysis of Continuous Variables**

# %%
card_approval_df[['Age','Debt','YearsEmployed','CreditScore','Income']].corr()
# Out:
#                     Age      Debt  YearsEmployed  CreditScore    Income
# Age            1.000000  0.202177       0.391464     0.187327  0.018719
# Debt           0.202177  1.000000       0.298902     0.271207  0.123121
# YearsEmployed  0.391464  0.298902       1.000000     0.322330  0.051345
# CreditScore    0.187327  0.271207       0.322330     1.000000  0.063692
# Income         0.018719  0.123121       0.051345     0.063692  1.000000

# %%
sns.scatterplot(card_approval_df.YearsEmployed, card_approval_df.Income)
plt.ylim(0,20000)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 20000.0)

# %%
sns.scatterplot(card_approval_df.YearsEmployed, card_approval_df.Age)
plt.ylim(0,20000)
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 20000.0)

# %%
card_approval_df.groupby(by = 'Approved').agg('mean')[['Age','Debt','YearsEmployed','CreditScore','Income']]
# Out:
#                 Age      Debt  YearsEmployed  CreditScore       Income
# Approved
# 0         29.773029  3.839948       1.257924     0.631854   198.605744
# 1         33.686221  5.904951       3.427899     4.605863  2038.859935

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data= card_approval_df,x ='Age',hue= 'Approved',fill = True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data= card_approval_df,x ='YearsEmployed',hue= 'Approved',fill = True)
# Out:
# <AxesSubplot:xlabel='YearsEmployed', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data= card_approval_df,x ='CreditScore',hue= 'Approved',fill = True)
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Density'>

# %% [markdown]
# ### **Bivariate Analysis of Categorical Variables vs Categorical Variables**

# %%
sns.countplot(data= card_approval_df, x='Approved',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Approved', ylabel='count'>

# %%
pd.crosstab(card_approval_df.Gender,card_approval_df.Approved,margins=True)
# Out:
# Approved    0    1  All
# Gender
# 0         112   98  210
# 1         271  209  480
# All       383  307  690

# %%
# Percentile of above crosstab
all=pd.crosstab(card_approval_df.Gender,card_approval_df.Approved,margins=True)['All']
pd.crosstab(card_approval_df.Gender,card_approval_df.Approved).divide(all,axis=0).dropna()
# Out:
# Approved         0         1
# Gender
# 0         0.533333  0.466667
# 1         0.564583  0.435417

# %%
sns.countplot(data= card_approval_df, x='Employed',hue='Approved')
# Out:
# <AxesSubplot:xlabel='Employed', ylabel='count'>

# %%
sns.countplot(data= card_approval_df, x='BankCustomer',hue='Approved')
# Out:
# <AxesSubplot:xlabel='BankCustomer', ylabel='count'>

# %%
sns.countplot(data= card_approval_df, x='Ethnicity',hue='Approved')
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
card_approval_df.groupby(by='Approved').agg('mean')[['Age','Debt','YearsEmployed','CreditScore','Income']]
# Out:
#                 Age      Debt  YearsEmployed  CreditScore       Income
# Approved
# 0         29.773029  3.839948       1.257924     0.631854   198.605744
# 1         33.686221  5.904951       3.427899     4.605863  2038.859935

# %%
card_approval_df[card_approval_df.Ethnicity=='Latino'][['Age','Debt','YearsEmployed','CreditScore','Income']].agg('mean')
# Out:
# Age               38.024386
# Debt               5.377105
# YearsEmployed      1.406316
# CreditScore        1.859649
# Income           434.649123
# dtype: float64

# %% [markdown]
# ### **Multivariate Analysis**
#
# Multivariate analysis is a more complex form of a statistical analysis technique and is used when there are more than two variables in the data set.

# %%
sns.pairplot(data=card_approval_df[['Age','Debt','YearsEmployed','CreditScore','Income','Approved']], hue='Approved')
